# %% [markdown]
# # The Iris Dataset
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The dataset contains a set of 150 records under five attributes - petal length, petal width, sepal length, sepal width and species.

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Import dataset
# - Import iris dataset
# - Import the dataset using sklearn library

# %%
from sklearn.datasets import load_iris
x = load_iris()

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - you can get the features using .data method
# - you can get the features using .target method

# %%
X=x.data
y=x.target

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
from sklearn.model_selection import train_test_split
test_size = 0.30
seed = 7 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### One-hot encode the labels
# - convert class vectors (integers) to binary class matrix
# - convert labels
# - number of classes: 3
# - we are doing this to use categorical_crossentropy as loss

# %%
from keras.utils import to_categorical
y_train=to_categorical(y_train,num_classes=3)
y_test=to_categorical(y_test,num_classes=3)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Initialize a sequential model
# - Define a sequential model

# %% [markdown]
# The sequential API allows you to create models layer-by-layer for most problems. It is limited in that it does not allow you to create models that share layers or have multiple inputs or outputs.

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Add a layer
# - Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3
# - Apply Softmax on Dense Layer outputs

# %%
model.add(tf.keras.layers.Dense(3,input_shape=(4,),activation='softmax'))

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Compile the model
# - Use SGD as Optimizer
# - Use categorical_crossentropy as loss function
# - Use accuracy as metrics

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Summarize the model
# - Check model layers
# - Understand number of trainable parameters

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 3)                 15
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Fit the model
# - Give train data as training features and labels
# - Epochs: 100
# - Give validation data as testing features and labels

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100)
# Out:
# Train on 105 samples, validate on 45 samples
# Epoch 1/100
# 105/105 [==============================] - 1s 5ms/sample - loss: 2.6249 - accuracy: 0.3619 - val_loss: 2.0676 - val_accuracy: 0.2667
# Epoch 2/100
# 105/105 [==============================] - 0s 215us/sample - loss: 1.6649 - accuracy: 0.3619 - val_loss: 1.4904 - val_accuracy: 0.1556
# Epoch 3/100
# 105/105 [==============================] - 0s 293us/sample - loss: 1.3363 - accuracy: 0.2000 - val_loss: 1.3252 - val_accuracy: 0.0222
# Epoch 4/100
# 105/105 [==============================] - 0s 230us/sample - loss: 1.2434 - accuracy: 0.0857 - val_loss: 1.2319 - val_accuracy: 0.2000
# Epoch 5/100
# 105/105 [==============================] - 0s 247us/sample - loss: 1.1763 - accuracy: 0.1905 - val_loss: 1.1825 - val_accuracy: 0.2444
# Epoch 6/100
# 105/105 [==============================] - 0s 214us/sample - loss: 1.1343 - accuracy: 0.2381 - val_loss: 1.1206 - val_accuracy: 0.2667
# Epoch 7/100
# 105/105 [==============================] - 0s 212us/sample - loss: 1.0970 - accuracy: 0.2762 - val_loss: 1.1064 - val_accuracy: 0.2000
# Epoch 8/100
# 105/105 [==============================] - 0s 243us/sample - loss: 1.0594 - accuracy: 0.2952 - val_loss: 1.0648 - val_accuracy: 0.2222
# Epoch 9/100
# 105/105 [==============================] - 0s 216us/sample - loss: 1.0317 - accuracy: 0.2571 - val_loss: 1.0387 - val_accuracy: 0.2222
# Epoch 10/100
# 105/105 [==============================] - 0s 210us/sample - loss: 1.0032 - accuracy: 0.4000 - val_loss: 1.0176 - val_accuracy: 0.2667
# Epoch 11/100
# 105/105 [==============================] - 0s 231us/sample - loss: 0.9812 - accuracy: 0.2762 - val_loss: 1.0001 - val_accuracy: 0.3111
# Epoch 12/100
# 105/105 [==============================] - 0s 243us/sample - loss: 0.9548 - accuracy: 0.3524 - val_loss: 0.9771 - val_accuracy: 0.5333
# Epoch 13/100
# 105/105 [==============================] - 0s 223us/sample - loss: 0.9253 - accuracy: 0.5143 - val_loss: 0.9474 - val_accuracy: 0.4889
# Epoch 14/100
# 105/105 [==============================] - 0s 231us/sample - loss: 0.8991 - accuracy: 0.5524 - val_loss: 0.9342 - val_accuracy: 0.5333
# Epoch 15/100
# 105/105 [==============================] - 0s 217us/sample - loss: 0.8781 - accuracy: 0.6381 - val_loss: 0.9185 - val_accuracy: 0.5556
# Epoch 16/100
# 105/105 [==============================] - 0s 196us/sample - loss: 0.8637 - accuracy: 0.7048 - val_loss: 0.8969 - val_accuracy: 0.5778
# Epoch 17/100
# 105/105 [==============================] - 0s 226us/sample - loss: 0.8441 - accuracy: 0.6381 - val_loss: 0.8978 - val_accuracy: 0.6000
# Epoch 18/100
# 105/105 [==============================] - 0s 222us/sample - loss: 0.8364 - accuracy: 0.7048 - val_loss: 0.8552 - val_accuracy: 0.6444
# Epoch 19/100
# 105/105 [==============================] - 0s 290us/sample - loss: 0.8254 - accuracy: 0.6667 - val_loss: 0.8499 - val_accuracy: 0.5556
# Epoch 20/100
# 105/105 [==============================] - 0s 224us/sample - loss: 0.7951 - accuracy: 0.7143 - val_loss: 0.8366 - val_accuracy: 0.5778
# Epoch 21/100
# 105/105 [==============================] - 0s 220us/sample - loss: 0.7802 - accuracy: 0.6952 - val_loss: 0.8229 - val_accuracy: 0.6667
# Epoch 22/100
# 105/105 [==============================] - 0s 232us/sample - loss: 0.7643 - accuracy: 0.6952 - val_loss: 0.8064 - val_accuracy: 0.6000
# Epoch 23/100
# 105/105 [==============================] - 0s 223us/sample - loss: 0.7546 - accuracy: 0.6762 - val_loss: 0.7998 - val_accuracy: 0.6444
# Epoch 24/100
# 105/105 [==============================] - 0s 241us/sample - loss: 0.7414 - accuracy: 0.6952 - val_loss: 0.7989 - val_accuracy: 0.5778
# Epoch 25/100
# 105/105 [==============================] - 0s 218us/sample - loss: 0.7358 - accuracy: 0.6667 - val_loss: 0.7738 - val_accuracy: 0.6889
# Epoch 26/100
# 105/105 [==============================] - 0s 203us/sample - loss: 0.7205 - accuracy: 0.7238 - val_loss: 0.7657 - val_accuracy: 0.6444
# Epoch 27/100
# 105/105 [==============================] - 0s 223us/sample - loss: 0.7055 - accuracy: 0.7048 - val_loss: 0.7554 - val_accuracy: 0.6889
# Epoch 28/100
# 105/105 [==============================] - 0s 243us/sample - loss: 0.6975 - accuracy: 0.7143 - val_loss: 0.7461 - val_accuracy: 0.5778
# Epoch 29/100
# 105/105 [==============================] - 0s 251us/sample - loss: 0.6918 - accuracy: 0.7048 - val_loss: 0.7352 - val_accuracy: 0.6222
# Epoch 30/100
# 105/105 [==============================] - 0s 237us/sample - loss: 0.6783 - accuracy: 0.7143 - val_loss: 0.7274 - val_accuracy: 0.7333
# Epoch 31/100
# 105/105 [==============================] - 0s 243us/sample - loss: 0.6700 - accuracy: 0.6952 - val_loss: 0.7226 - val_accuracy: 0.6000
# Epoch 32/100
# 105/105 [==============================] - 0s 226us/sample - loss: 0.6618 - accuracy: 0.7238 - val_loss: 0.7130 - val_accuracy: 0.6889
# Epoch 33/100
# 105/105 [==============================] - 0s 229us/sample - loss: 0.6584 - accuracy: 0.7048 - val_loss: 0.7124 - val_accuracy: 0.6889
# Epoch 34/100
# 105/105 [==============================] - 0s 231us/sample - loss: 0.6487 - accuracy: 0.7714 - val_loss: 0.6993 - val_accuracy: 0.7333
# Epoch 35/100
# 105/105 [==============================] - 0s 239us/sample - loss: 0.6374 - accuracy: 0.7429 - val_loss: 0.6937 - val_accuracy: 0.6222
# Epoch 36/100
# 105/105 [==============================] - 0s 199us/sample - loss: 0.6357 - accuracy: 0.7143 - val_loss: 0.6870 - val_accuracy: 0.6889
# Epoch 37/100
# 105/105 [==============================] - 0s 226us/sample - loss: 0.6239 - accuracy: 0.7429 - val_loss: 0.6824 - val_accuracy: 0.6889
# Epoch 38/100
# 105/105 [==============================] - 0s 237us/sample - loss: 0.6193 - accuracy: 0.7143 - val_loss: 0.6835 - val_accuracy: 0.6889
# Epoch 39/100
# 105/105 [==============================] - 0s 247us/sample - loss: 0.6246 - accuracy: 0.7524 - val_loss: 0.6842 - val_accuracy: 0.6667
# Epoch 40/100
# 105/105 [==============================] - 0s 228us/sample - loss: 0.6172 - accuracy: 0.7524 - val_loss: 0.6643 - val_accuracy: 0.7333
# Epoch 41/100
# 105/105 [==============================] - 0s 221us/sample - loss: 0.6025 - accuracy: 0.7905 - val_loss: 0.6605 - val_accuracy: 0.7333
# Epoch 42/100
# 105/105 [==============================] - 0s 212us/sample - loss: 0.5960 - accuracy: 0.7714 - val_loss: 0.6560 - val_accuracy: 0.7333
# Epoch 43/100
# 105/105 [==============================] - 0s 199us/sample - loss: 0.5911 - accuracy: 0.7810 - val_loss: 0.6516 - val_accuracy: 0.7111
# Epoch 44/100
# 105/105 [==============================] - 0s 210us/sample - loss: 0.5882 - accuracy: 0.7238 - val_loss: 0.6514 - val_accuracy: 0.7556
# Epoch 45/100
# 105/105 [==============================] - 0s 244us/sample - loss: 0.5835 - accuracy: 0.8000 - val_loss: 0.6422 - val_accuracy: 0.7556
# Epoch 46/100
# 105/105 [==============================] - 0s 215us/sample - loss: 0.5773 - accuracy: 0.7810 - val_loss: 0.6381 - val_accuracy: 0.7556
# Epoch 47/100
# 105/105 [==============================] - 0s 242us/sample - loss: 0.5720 - accuracy: 0.8095 - val_loss: 0.6383 - val_accuracy: 0.6222
# Epoch 48/100
# 105/105 [==============================] - 0s 240us/sample - loss: 0.5737 - accuracy: 0.7238 - val_loss: 0.6310 - val_accuracy: 0.6667
# Epoch 49/100
# 105/105 [==============================] - 0s 221us/sample - loss: 0.5657 - accuracy: 0.7524 - val_loss: 0.6271 - val_accuracy: 0.7556
# Epoch 50/100
# 105/105 [==============================] - 0s 311us/sample - loss: 0.5595 - accuracy: 0.7905 - val_loss: 0.6242 - val_accuracy: 0.6444
# Epoch 51/100
# 105/105 [==============================] - 0s 234us/sample - loss: 0.5606 - accuracy: 0.7429 - val_loss: 0.6230 - val_accuracy: 0.6444
# Epoch 52/100
# 105/105 [==============================] - 0s 240us/sample - loss: 0.5532 - accuracy: 0.7524 - val_loss: 0.6182 - val_accuracy: 0.6444
# Epoch 53/100
# 105/105 [==============================] - 0s 232us/sample - loss: 0.5475 - accuracy: 0.7333 - val_loss: 0.6104 - val_accuracy: 0.7556
# Epoch 54/100
# 105/105 [==============================] - 0s 248us/sample - loss: 0.5424 - accuracy: 0.8286 - val_loss: 0.6074 - val_accuracy: 0.7556
# Epoch 55/100
# 105/105 [==============================] - 0s 241us/sample - loss: 0.5431 - accuracy: 0.7524 - val_loss: 0.6054 - val_accuracy: 0.7778
# Epoch 56/100
# 105/105 [==============================] - 0s 245us/sample - loss: 0.5371 - accuracy: 0.8190 - val_loss: 0.6052 - val_accuracy: 0.7556
# Epoch 57/100
# 105/105 [==============================] - 0s 260us/sample - loss: 0.5346 - accuracy: 0.8190 - val_loss: 0.6021 - val_accuracy: 0.6667
# Epoch 58/100
# 105/105 [==============================] - 0s 238us/sample - loss: 0.5325 - accuracy: 0.7333 - val_loss: 0.5976 - val_accuracy: 0.7778
# Epoch 59/100
# 105/105 [==============================] - 0s 274us/sample - loss: 0.5302 - accuracy: 0.8000 - val_loss: 0.5950 - val_accuracy: 0.7333
# Epoch 60/100
# 105/105 [==============================] - 0s 217us/sample - loss: 0.5241 - accuracy: 0.7714 - val_loss: 0.5927 - val_accuracy: 0.6667
# Epoch 61/100
# 105/105 [==============================] - 0s 257us/sample - loss: 0.5205 - accuracy: 0.7524 - val_loss: 0.5906 - val_accuracy: 0.7778
# Epoch 62/100
# 105/105 [==============================] - 0s 240us/sample - loss: 0.5197 - accuracy: 0.8190 - val_loss: 0.5859 - val_accuracy: 0.8000
# Epoch 63/100
# 105/105 [==============================] - 0s 251us/sample - loss: 0.5162 - accuracy: 0.8095 - val_loss: 0.5854 - val_accuracy: 0.8000
# Epoch 64/100
# 105/105 [==============================] - 0s 239us/sample - loss: 0.5162 - accuracy: 0.8381 - val_loss: 0.5793 - val_accuracy: 0.7556
# Epoch 65/100
# 105/105 [==============================] - 0s 220us/sample - loss: 0.5119 - accuracy: 0.8000 - val_loss: 0.5767 - val_accuracy: 0.7778
# Epoch 66/100
# 105/105 [==============================] - 0s 218us/sample - loss: 0.5067 - accuracy: 0.8381 - val_loss: 0.5730 - val_accuracy: 0.7556
# Epoch 67/100
# 105/105 [==============================] - 0s 230us/sample - loss: 0.5033 - accuracy: 0.8190 - val_loss: 0.5696 - val_accuracy: 0.8222
# Epoch 68/100
# 105/105 [==============================] - 0s 218us/sample - loss: 0.5027 - accuracy: 0.8286 - val_loss: 0.5679 - val_accuracy: 0.8222
# Epoch 69/100
# 105/105 [==============================] - 0s 228us/sample - loss: 0.5014 - accuracy: 0.8190 - val_loss: 0.5654 - val_accuracy: 0.7778
# Epoch 70/100
# 105/105 [==============================] - 0s 232us/sample - loss: 0.4975 - accuracy: 0.8476 - val_loss: 0.5661 - val_accuracy: 0.7333
# Epoch 71/100
# 105/105 [==============================] - 0s 232us/sample - loss: 0.4968 - accuracy: 0.8095 - val_loss: 0.5646 - val_accuracy: 0.7333
# Epoch 72/100
# 105/105 [==============================] - 0s 238us/sample - loss: 0.4963 - accuracy: 0.7429 - val_loss: 0.5607 - val_accuracy: 0.8000
# Epoch 73/100
# 105/105 [==============================] - 0s 253us/sample - loss: 0.4893 - accuracy: 0.8476 - val_loss: 0.5575 - val_accuracy: 0.7778
# Epoch 74/100
# 105/105 [==============================] - 0s 239us/sample - loss: 0.4865 - accuracy: 0.8095 - val_loss: 0.5562 - val_accuracy: 0.8222
# Epoch 75/100
# 105/105 [==============================] - 0s 238us/sample - loss: 0.4866 - accuracy: 0.8476 - val_loss: 0.5538 - val_accuracy: 0.8222
# Epoch 76/100
# 105/105 [==============================] - 0s 231us/sample - loss: 0.4829 - accuracy: 0.8571 - val_loss: 0.5513 - val_accuracy: 0.7778
# Epoch 77/100
# 105/105 [==============================] - 0s 232us/sample - loss: 0.4799 - accuracy: 0.8095 - val_loss: 0.5505 - val_accuracy: 0.7556
# Epoch 78/100
# 105/105 [==============================] - 0s 217us/sample - loss: 0.4811 - accuracy: 0.8286 - val_loss: 0.5483 - val_accuracy: 0.8222
# Epoch 79/100
# 105/105 [==============================] - 0s 210us/sample - loss: 0.4767 - accuracy: 0.8667 - val_loss: 0.5450 - val_accuracy: 0.7778
# Epoch 80/100
# 105/105 [==============================] - 0s 227us/sample - loss: 0.4740 - accuracy: 0.8190 - val_loss: 0.5433 - val_accuracy: 0.8000
# Epoch 81/100
# 105/105 [==============================] - 0s 215us/sample - loss: 0.4714 - accuracy: 0.8571 - val_loss: 0.5437 - val_accuracy: 0.7333
# Epoch 82/100
# 105/105 [==============================] - 0s 215us/sample - loss: 0.4709 - accuracy: 0.8000 - val_loss: 0.5409 - val_accuracy: 0.7556
# Epoch 83/100
# 105/105 [==============================] - 0s 229us/sample - loss: 0.4690 - accuracy: 0.8000 - val_loss: 0.5399 - val_accuracy: 0.7333
# Epoch 84/100
# 105/105 [==============================] - 0s 305us/sample - loss: 0.4659 - accuracy: 0.8190 - val_loss: 0.5378 - val_accuracy: 0.7333
# Epoch 85/100
# 105/105 [==============================] - 0s 233us/sample - loss: 0.4664 - accuracy: 0.8095 - val_loss: 0.5389 - val_accuracy: 0.7333
# Epoch 86/100
# 105/105 [==============================] - 0s 206us/sample - loss: 0.4630 - accuracy: 0.8190 - val_loss: 0.5330 - val_accuracy: 0.8000
# Epoch 87/100
# 105/105 [==============================] - 0s 245us/sample - loss: 0.4622 - accuracy: 0.8381 - val_loss: 0.5378 - val_accuracy: 0.7111
# Epoch 88/100
# 105/105 [==============================] - 0s 241us/sample - loss: 0.4648 - accuracy: 0.8000 - val_loss: 0.5310 - val_accuracy: 0.7333
# Epoch 89/100
# 105/105 [==============================] - 0s 227us/sample - loss: 0.4579 - accuracy: 0.8190 - val_loss: 0.5271 - val_accuracy: 0.8222
# Epoch 90/100
# 105/105 [==============================] - 0s 211us/sample - loss: 0.4633 - accuracy: 0.8190 - val_loss: 0.5260 - val_accuracy: 0.7778
# Epoch 91/100
# 105/105 [==============================] - 0s 227us/sample - loss: 0.4564 - accuracy: 0.8286 - val_loss: 0.5252 - val_accuracy: 0.7556
# Epoch 92/100
# 105/105 [==============================] - 0s 214us/sample - loss: 0.4558 - accuracy: 0.8190 - val_loss: 0.5227 - val_accuracy: 0.8000
# Epoch 93/100
# 105/105 [==============================] - 0s 214us/sample - loss: 0.4505 - accuracy: 0.8476 - val_loss: 0.5218 - val_accuracy: 0.8444
# Epoch 94/100
# 105/105 [==============================] - 0s 255us/sample - loss: 0.4509 - accuracy: 0.8762 - val_loss: 0.5192 - val_accuracy: 0.8222
# Epoch 95/100
# 105/105 [==============================] - 0s 257us/sample - loss: 0.4501 - accuracy: 0.8571 - val_loss: 0.5176 - val_accuracy: 0.8222
# Epoch 96/100
# 105/105 [==============================] - 0s 241us/sample - loss: 0.4543 - accuracy: 0.8667 - val_loss: 0.5162 - val_accuracy: 0.8222
# Epoch 97/100
# 105/105 [==============================] - 0s 226us/sample - loss: 0.4442 - accuracy: 0.8476 - val_loss: 0.5153 - val_accuracy: 0.8000
# Epoch 98/100
# 105/105 [==============================] - 0s 227us/sample - loss: 0.4432 - accuracy: 0.8476 - val_loss: 0.5165 - val_accuracy: 0.7333
# Epoch 99/100
# 105/105 [==============================] - 0s 216us/sample - loss: 0.4426 - accuracy: 0.8190 - val_loss: 0.5123 - val_accuracy: 0.8000
# Epoch 100/100
# 105/105 [==============================] - 0s 213us/sample - loss: 0.4397 - accuracy: 0.8476 - val_loss: 0.5125 - val_accuracy: 0.7556

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Make predictions
# - Predict labels on one row

# %%
model.predict(X_test[:1])
# Out:
# array([[0.02452511, 0.3225293 , 0.65294564]], dtype=float32)

# %% [markdown]
# ### Compare the prediction with actual label
# - Print the same row as done in the previous step but of actual labels

# %%
print(y_test[:1])
# Out:
# [[0. 0. 1.]]

# %% [markdown]
# ---

# %% [markdown]
# # Stock prices dataset
# The data is of tock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab/prices-1.csv')
df
# Out:
#                        date symbol  ...        high     volume
# 0       2016-01-05 00:00:00   WLTW  ...  126.250000  2163600.0
# 1       2016-01-06 00:00:00   WLTW  ...  125.540001  2386400.0
# 2       2016-01-07 00:00:00   WLTW  ...  119.739998  2489500.0
# 3       2016-01-08 00:00:00   WLTW  ...  117.440002  2006300.0
# 4       2016-01-11 00:00:00   WLTW  ...  117.330002  1408600.0
# ...                     ...    ...  ...         ...        ...
# 851259           2016-12-30    ZBH  ...  103.930000   973800.0
# 851260           2016-12-30   ZION  ...   43.310001  1938100.0
# 851261           2016-12-30    ZTS  ...   53.740002  1701200.0
# 851262  2016-12-30 00:00:00    AIV  ...   45.590000  1380900.0
# 851263  2016-12-30 00:00:00    FTV  ...   54.480000   705100.0
#
# [851264 rows x 7 columns]

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Drop columnns
# - drop "date" and "symbol" column from the data

# %%
df.drop(columns=['date','symbol'],inplace=True)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Take initial rows
# - Take first 1000 rows from the data
# - This step is done to make the execution faster

# %%
df1=df.head(1000)
df1
# Out:
#            open       close         low        high      volume
# 0    123.430000  125.839996  122.309998  126.250000   2163600.0
# 1    125.239998  119.980003  119.940002  125.540001   2386400.0
# 2    116.379997  114.949997  114.930000  119.739998   2489500.0
# 3    115.480003  116.620003  113.500000  117.440002   2006300.0
# 4    117.010002  114.970001  114.089996  117.330002   1408600.0
# ..          ...         ...         ...         ...         ...
# 995   63.310001   63.590000   63.240002   63.639999   2133200.0
# 996   27.160000   26.990000   26.680000   27.299999   1982400.0
# 997   28.320000   28.770000   28.010000   28.809999  37152800.0
# 998   44.000000   44.799999   43.750000   44.810001   6568600.0
# 999   36.080002   37.139999   36.009998   37.230000   5604300.0
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Take "open", "close", "low", "high" columns as features
# - Take "volume" column as label
# - Normalize label column by dividing it with 1000000

# %%
y=df1['volume']/1000000
X=df1[(['open','close','low','high'])]

# %%
y
# Out:
# 0       2.1636
# 1       2.3864
# 2       2.4895
# 3       2.0063
# 4       1.4086
#         ...
# 995     2.1332
# 996     1.9824
# 997    37.1528
# 998     6.5686
# 999     5.6043
# Name: volume, Length: 1000, dtype: float64

# %%
X
# Out:
#            open       close         low        high
# 0    123.430000  125.839996  122.309998  126.250000
# 1    125.239998  119.980003  119.940002  125.540001
# 2    116.379997  114.949997  114.930000  119.739998
# 3    115.480003  116.620003  113.500000  117.440002
# 4    117.010002  114.970001  114.089996  117.330002
# ..          ...         ...         ...         ...
# 995   63.310001   63.590000   63.240002   63.639999
# 996   27.160000   26.990000   26.680000   27.299999
# 997   28.320000   28.770000   28.010000   28.809999
# 998   44.000000   44.799999   43.750000   44.810001
# 999   36.080002   37.139999   36.009998   37.230000
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Convert data
# - Convert features and labels to numpy array
# - Convert their data type to "float32"

# %%
import numpy as np
X=np.array(X).astype('float32')
y=np.array(y).astype('float32')

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Normalize data
# - Normalize features
# - Use tf.math.l2_normalize to normalize features
# - You can read more about it here https://www.tensorflow.org/api_docs/python/tf/math/l2_normalize

# %%
X = tf.math.l2_normalize(X)

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Define weight and bias
# - Initialize weight and bias with tf.zeros
# - tf.zeros is an initializer that generates tensors initialized to 0
# - Specify the value for shape

# %%
W = tf.zeros(shape=(4, 1))
b = tf.zeros(shape=(1))

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Get prediction
# - Define a function to get prediction
# - Approach: prediction = (X * W) + b; here is X is features

# %%
@tf.function
def prediction(X, W, b):
    y_pred = tf.add(tf.matmul(X,W), b)
    return y_pred

# %% [markdown]
# ### Calculate loss
# - Calculate loss using predictions
# - Define a function to calculate loss
# - We are calculating mean squared error

# %%
@tf.function
def loss(y, y_pred):
    diff = y- y_pred
    sqr = tf.square(diff)
    avg = tf.reduce_mean(sqr)
    return avg

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Define a function to train the model
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
@tf.function
def train(X, y, W, b, learning_rate=0.01):
    
    # Record mathematical operations on 'tape' to calculate loss
    with tf.GradientTape() as t:
        t.watch([W,b])
        current_prediction = prediction(X, W, b)
        current_loss = loss(y, current_prediction)
    
    # Calculate Gradients for Loss with respect to Weights and Bias
    dw, db = t.gradient(current_loss,[W, b])
    
    # Update Weights and Bias
    W = W - learning_rate * dw
    b = b - learning_rate * db
    
    return W, b

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Train the model for 100 epochs
# - Observe the training loss at every iteration

# %%
for i in range(100):    
    W, b = train(X, y, W, b)
    print('Current Training Loss on iteration', i, loss(y, prediction(X, W, b)).numpy())
# Out:
# Current Training Loss on iteration 0 236.16759
# Current Training Loss on iteration 1 235.09299
# Current Training Loss on iteration 2 234.06102
# Current Training Loss on iteration 3 233.06998
# Current Training Loss on iteration 4 232.11781
# Current Training Loss on iteration 5 231.20381
# Current Training Loss on iteration 6 230.32585
# Current Training Loss on iteration 7 229.48265
# Current Training Loss on iteration 8 228.67297
# Current Training Loss on iteration 9 227.89539
# Current Training Loss on iteration 10 227.14832
# Current Training Loss on iteration 11 226.43114
# Current Training Loss on iteration 12 225.74234
# Current Training Loss on iteration 13 225.0808
# Current Training Loss on iteration 14 224.44553
# Current Training Loss on iteration 15 223.835
# Current Training Loss on iteration 16 223.24931
# Current Training Loss on iteration 17 222.68655
# Current Training Loss on iteration 18 222.14595
# Current Training Loss on iteration 19 221.62688
# Current Training Loss on iteration 20 221.12842
# Current Training Loss on iteration 21 220.6498
# Current Training Loss on iteration 22 220.18993
# Current Training Loss on iteration 23 219.74841
# Current Training Loss on iteration 24 219.32425
# Current Training Loss on iteration 25 218.91705
# Current Training Loss on iteration 26 218.52579
# Current Training Loss on iteration 27 218.15027
# Current Training Loss on iteration 28 217.78957
# Current Training Loss on iteration 29 217.44315
# Current Training Loss on iteration 30 217.11034
# Current Training Loss on iteration 31 216.79077
# Current Training Loss on iteration 32 216.48412
# Current Training Loss on iteration 33 216.18932
# Current Training Loss on iteration 34 215.90611
# Current Training Loss on iteration 35 215.63437
# Current Training Loss on iteration 36 215.37334
# Current Training Loss on iteration 37 215.12263
# Current Training Loss on iteration 38 214.88185
# Current Training Loss on iteration 39 214.65053
# Current Training Loss on iteration 40 214.42859
# Current Training Loss on iteration 41 214.21527
# Current Training Loss on iteration 42 214.01044
# Current Training Loss on iteration 43 213.81369
# Current Training Loss on iteration 44 213.62482
# Current Training Loss on iteration 45 213.44333
# Current Training Loss on iteration 46 213.2691
# Current Training Loss on iteration 47 213.10179
# Current Training Loss on iteration 48 212.94106
# Current Training Loss on iteration 49 212.78687
# Current Training Loss on iteration 50 212.63857
# Current Training Loss on iteration 51 212.4961
# Current Training Loss on iteration 52 212.35948
# Current Training Loss on iteration 53 212.22816
# Current Training Loss on iteration 54 212.10205
# Current Training Loss on iteration 55 211.98093
# Current Training Loss on iteration 56 211.86461
# Current Training Loss on iteration 57 211.75293
# Current Training Loss on iteration 58 211.64558
# Current Training Loss on iteration 59 211.54266
# Current Training Loss on iteration 60 211.44374
# Current Training Loss on iteration 61 211.34874
# Current Training Loss on iteration 62 211.2575
# Current Training Loss on iteration 63 211.16982
# Current Training Loss on iteration 64 211.08572
# Current Training Loss on iteration 65 211.00484
# Current Training Loss on iteration 66 210.92729
# Current Training Loss on iteration 67 210.85278
# Current Training Loss on iteration 68 210.78104
# Current Training Loss on iteration 69 210.71225
# Current Training Loss on iteration 70 210.64633
# Current Training Loss on iteration 71 210.58289
# Current Training Loss on iteration 72 210.52199
# Current Training Loss on iteration 73 210.46347
# Current Training Loss on iteration 74 210.4073
# Current Training Loss on iteration 75 210.3533
# Current Training Loss on iteration 76 210.30153
# Current Training Loss on iteration 77 210.2518
# Current Training Loss on iteration 78 210.204
# Current Training Loss on iteration 79 210.15811
# Current Training Loss on iteration 80 210.1141
# Current Training Loss on iteration 81 210.0717
# Current Training Loss on iteration 82 210.03108
# Current Training Loss on iteration 83 209.99205
# Current Training Loss on iteration 84 209.95453
# Current Training Loss on iteration 85 209.91852
# Current Training Loss on iteration 86 209.88396
# Current Training Loss on iteration 87 209.85075
# Current Training Loss on iteration 88 209.81891
# Current Training Loss on iteration 89 209.78818
# Current Training Loss on iteration 90 209.75874
# Current Training Loss on iteration 91 209.73053
# Current Training Loss on iteration 92 209.70349
# Current Training Loss on iteration 93 209.67744
# Current Training Loss on iteration 94 209.65225
# Current Training Loss on iteration 95 209.62833
# Current Training Loss on iteration 96 209.6052
# Current Training Loss on iteration 97 209.58302
# Current Training Loss on iteration 98 209.56174
# Current Training Loss on iteration 99 209.5413

# %% [markdown]
# ### Observe values of Weight
# - Print the updated values

# %%
W.numpy()
# Out:
# array([[0.0547828 ],
#        [0.05488191],
#        [0.05422735],
#        [0.05533117]], dtype=float32)

# %% [markdown]
# ### Observe values of Bias
# - Print the updated values

# %%
b.numpy()
# Out:
# array([4.607657], dtype=float32)
